# %% [markdown]
# collect_news_crawling.ipynb
# 1. 크롤링 타겟 URL 확인
# 2. 크롤링 함수 작성
# 3. 기간별 뉴스 수집
# 4. CSV 저장
# 5. Supabase 업로드

# %% [markdown]
# ## 라이브러리 import

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import time

# %% [markdown]
# ## 기본설정

# %%
# User-Agent 설정
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
}

# BASE_URL = 'https://www.joongang.co.kr/realestate'
BASE_URL = 'https://www.joongang.co.kr/realestate/news'

# 검색 키워드
KEYWORDS = ['부동산', '아파트', '집값']

# %% [markdown]
# ## 뉴스 크롤링 함수

# %%
# def crwl_joongang_realestate(start_page=1, end_page=5):
def crwl_joongang_realestate():
    """
    중앙일보 부동산 섹션 크롤링

    Parameters:
    - start_page: 시작 페이지 (1부터 시작)
    - end_page: 종료 페이지
    """

    all_news = []

    # for page in range(start_page, end_page + 1):
    #     if page == 1:
    #         url = BASE_URL
    #     else:
    #         url = f"{BASE_URL}?page={page}"
        
    
    try:
        response = requests.get(BASE_URL, headers=HEADERS, timeout=10)

        if response.status_code != 200:
            print(f"실패: {response.status_code}")
            # continue

        soup = BeautifulSoup(response.content, 'html.parser')

        # print(soup.select('h2.headline'))


        cards = soup.select('li.card')

        print(f"총 {len(cards)}개 카드 찾음!")

        
        news_list = []

        for card in cards:
            headline = card.select_one('h2.headline')
            date = card.select_one('p.date')
            link = card.select_one('a')

            if headline:  # 제목이 있을 때만
                news_list.append({
                    '제목': headline.get_text(strip=True),
                    '날짜': date.get_text(strip=True) if date else '',
                    'URL': link['href'] if link else ''
                })
    
    except Exception as e:
        print(e)

    for i, news in enumerate(news_list, 1):
        print(f"{i}. {news['제목']}")
        print(f"   날짜: {news['날짜']}")
        print(f"   URL: {news['URL']}")
        print()

# %%
crwl_joongang_realestate()
# Out:
# 총 30개 카드 찾음!
# 1. 해외건설 수주 473억 달러, 11년 만에 최대…“체코 원전이 효자”
#    날짜: 2026.01.09 11:48
#    URL: https://www.joongang.co.kr/article/25396332
#
# 2. “규정 안 어겼다”더니…국토부 “무안공항 로컬라이저 규정 위반”
#    날짜: 2026.01.09 00:43
#    URL: https://www.joongang.co.kr/article/25396247
#
# 3. 서울 ‘국평’ 평균 분양가 19억 돌파…전국 평균은 7억
#    날짜: 2026.01.09 00:01
#    URL: https://www.joongang.co.kr/article/25396196
#
# 4. "제주항공 참사, 둔덕 없었으면 전원생존"…국토부 입장 바꿨다
#    날짜: 2026.01.08 18:18
#    URL: https://www.joongang.co.kr/article/25396161
#
# 5. 지난달 서울 ‘국평’ 분양가 19억원…전국도 7억 돌파
#    날짜: 2026.01.08 15:11
#    URL: https://www.joongang.co.kr/article/25396082
#
# 6. 불장 송파의 미묘한 변화…서잠실→동잠실로 중심축 이동하나
#    날짜: 2026.01.07 18:53
#    URL: https://www.joongang.co.kr/article/25395884
#
# 7. “서울 아파트 살래”…작년 서울 원정투자 외지인 4년 만에 최다
#    날짜: 2026.01.07 15:33
#    URL: https://www.joongang.co.kr/article/25395800
#
# 8. 굴포천역 남측 도심 공공주택 복합사업 본격화
#    날짜: 2026.01.07 14:53
#    URL: https://www.joongang.co.kr/article/25395775
#
# 9. 인천∼자카르타 노선에 티웨이…대한항공·아시아나 대체사 선정
#    날짜: 2026.01.06 11:44
#    URL: https://www.joongang.co.kr/article/25395462
#
# 10. "요즘 애들, 회사도 입지 따져"…이유있는 '프라임 오피스' 전성시대
#    날짜: 2026.01.06 05:00
#    URL: https://www.joongang.co.kr/article/25395395
#
# 11. [사진] 서울 전세→월세 전환 5년만에 최다
#    날짜: 2026.01.06 00:01
#    URL: https://www.joongang.co.kr/article/25395327
#
# 12. 반포·서초·방배·흑석…새해도 ‘로또 기회’ 계속 옵니다
#    날짜: 2026.01.05 00:01
#    URL: https://www.joongang.co.kr/article/25395020
#
# 13. 반포·방배·흑석…올해 알짜 분양단지는 어디
#    날짜: 2026.01.04 15:52
#    URL: https://www.joongang.co.kr/article/25394964
#
# 14. 국토부, 주택공급 전담조직 출범…“수도권 135만호 공급 목표”
#    날짜: 2026.01.02 10:53
#    URL: https://www.joongang.co.kr/article/25394633
#
# 15. 송파 21% 성동 19%↑…결국 문 정부 ‘미친 집값’ 넘었다
#    날짜: 2026.01.02 00:38
#    URL: https://www.joongang.co.kr/article/25394588
#
# 16. 서울 아파트값 상승률, ‘문 정부 집값’ 넘었다…준강남까지 들썩
#    날짜: 2026.01.01 14:14
#    URL: https://www.joongang.co.kr/article/25394462
#
# 17. 기관도 학계도 시장도…“새해 서울 집값 오를 것”
#    날짜: 2026.01.01 00:01
#    URL: https://www.joongang.co.kr/article/25394350
#
# 18. “10·15 대책 집값 못잡고 자산격차 심화”…“내년 전월세 더 오른다”
#    날짜: 2025.12.31 14:21
#    URL: https://www.joongang.co.kr/article/25394228
#
# 19. 수도권 7곳 공공주택지구 계획 승인·지정…13.3만 가구 공급 본격화
#    날짜: 2025.12.31 11:53
#    URL: https://www.joongang.co.kr/article/25394199
#
# 20. 10·15 대책 ‘3중 규제’에 11월 서울 아파트 거래 60% 줄었다
#    날짜: 2025.12.31 10:47
#    URL: https://www.joongang.co.kr/article/25394177
#
# 21. 사망사고 낸 항공사, 1년간 새 노선 못 얻는다…항공운전 규제 대폭 강화
#    날짜: 2025.12.30 11:40
#    URL: https://www.joongang.co.kr/article/25393854
#
# 22. 회삿돈 38억 빌려 49억 아파트 구매…수상한 외국인들 딱 걸렸다
#    날짜: 2025.12.30 11:01
#    URL: https://www.joongang.co.kr/article/25393839
#
# 23. 1년 내내 '국토부 셀프조사' 논란…아직도 진상규명 못했다
#    날짜: 2025.12.29 00:27
#    URL: https://www.joongang.co.kr/article/25393378
#
# 24. [사진] 치솟는 서울 전셋값…올해 재계약 절반이 ‘갱신권’
#    날짜: 2025.12.29 00:01
#    URL: https://www.joongang.co.kr/article/25393330
